# %% [markdown]
# <a href="https://colab.research.google.com/github/Thiago251/raspagemtabelasite/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'http://voos.infraero.gov.br/hstvoos/RelatorioPortal.aspx'

# %%
html = pd.read_html(url, match='PROGRAMADOS')

# %%
BB = html[0]

# %%
BB
# Out:
#                      PROGRAMADOS  ...  CANCELADOS (%)
# 0                         TOTAIS  ...   7  (  1.3  %)
# 1                    Altamira-PA  ...     0  (  0  %)
# 2                     Aracaju-SE  ...     0  (  0  %)
# 3                       Belém-PA  ...     0  (  0  %)
# 4                   Boa Vista-RR  ...     0  (  0  %)
# 5              Campina Grande-PB  ...     0  (  0  %)
# 6                Campo Grande-MS  ...     0  (  0  %)
# 7                     Carajás-PA  ...     0  (  0  %)
# 8                      Cuiabá-MT  ...     0  (  0  %)
# 9                    Curitiba-PR  ...  6  (  15.8  %)
# 10              Foz Do Iguaçu-PR  ...     0  (  0  %)
# 11                    Goiânia-GO  ...     0  (  0  %)
# 12                 Imperatriz-MA  ...     0  (  0  %)
# 13                Joao Pessoa-PB  ...     0  (  0  %)
# 14                  Joinville-SC  ...     0  (  0  %)
# 15          Juazeiro Do Norte-CE  ...     0  (  0  %)
# ...

# %%
BB.to_csv('teste.csv')
